# %% [markdown]
# <a href="https://colab.research.google.com/github/SanthoshKumarHitter/Machine-Learning/blob/main/K_Means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import silhouette_score

# %% [markdown]
# # Load the iris dataset

# %%
iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)

# %% [markdown]
# # Scale the features using MinMaxScaler

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Initialize the KMeans clustering model

# %%
k = 3
kmeans = KMeans(n_clusters=k, n_init=10, random_state=42)

# %% [markdown]
# # Fit the model to the scaled data

# %%
kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=3, n_init=10, random_state=42)

# %% [markdown]
# # Predict the clusters

# %%
labels = kmeans.labels_

# %% [markdown]
# # Calculate silhouette score

# %%
silhouette_avg = silhouette_score(X_scaled, labels)
print("Silhouette Score:", silhouette_avg)
# Out:
# Silhouette Score: 0.5047687565398589

# %% [markdown]
# # Add cluster labels to the DataFrame

# %%
X['Cluster'] = labels

# %% [markdown]
# # Plot the clusters

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=X, x='sepal length (cm)', y='sepal width (cm)', hue='Cluster', palette='viridis')
plt.title('K-Means Clustering of Iris Dataset')
plt.show()
