# %% [markdown]
# <a href="https://colab.research.google.com/github/SanthoshKumarHitter/Machine-Learning/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# # Load the iris dataset

# %%
iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)

# %% [markdown]
# # Standardize the features

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Initialize PCA with 2 principal components

# %%
pca = PCA(n_components=2)

# %% [markdown]
# # Fit PCA to the scaled data

# %%
X_pca = pca.fit_transform(X_scaled)

# %% [markdown]
# # Plot the PCA-transformed data

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=iris.target, cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Iris Dataset')
plt.colorbar(label='Target')
plt.show()
